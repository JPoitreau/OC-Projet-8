# %%
import os
import pandas as pd

# %%
data = pd.read_csv('../../data/original/demonstration_data.csv', sep = ';')
explicative_variables = ['EXT_SOURCE_1', 
                         'EXT_SOURCE_2', 
                         'EXT_SOURCE_3', 
                         'client_installments_AMT_PAYMENT_min_sum',
                         'DAYS_EMPLOYED',
                         'AMT_CREDIT',
                         'DAYS_BIRTH',
                         'previous_CNT_PAYMENT_mean',
                         'bureau_DAYS_CREDIT_max',
                         'client_cash_CNT_INSTALMENT_FUTURE_min_mean']
explicative_data = data.loc[:,explicative_variables]

# %%
explicative_data.head()
# Out:
#    EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# 0      0.752614      0.789654      0.159520
# 1      0.564990      0.291656      0.432962
# 2           NaN      0.699787      0.610991
# 3      0.525734      0.509677      0.612704
# 4      0.202145      0.425687           NaN
#
#    client_installments_AMT_PAYMENT_min_sum  DAYS_EMPLOYED  AMT_CREDIT  \
# 0                                27746.775        -2329.0    568800.0
# 1                                43318.800        -4469.0    222768.0
# 2                                66875.266        -4458.0    663264.0
# 3                               172044.310        -1866.0   1575000.0
# 4                               133169.400        -2191.0    625500.0
#
#    DAYS_BIRTH  previous_CNT_PAYMENT_mean  bureau_DAYS_CREDIT_max  \
# 0      -19241                   8.000000                   -49.0
# 1      -18064                  12.000000                   -62.0
# 2      -20038                  17.333334                 -1210.0
# ...

# %%
explicative_data.describe()
# Out:
#        EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# count     29.000000     49.000000     45.000000
# mean       0.550443      0.548033      0.467359
# std        0.190442      0.177338      0.185815
# min        0.202145      0.090922      0.159520
# 25%        0.398751      0.394268      0.312365
# 50%        0.583118      0.600999      0.474051
# 75%        0.696565      0.684407      0.612704
# max        0.866010      0.808788      0.821443
#
#        client_installments_AMT_PAYMENT_min_sum  DAYS_EMPLOYED    AMT_CREDIT  \
# count                             4.700000e+01      43.000000  4.900000e+01
# mean                              4.419494e+05   -2643.790698  5.129940e+05
# std                               7.761405e+05    2511.476217  3.429715e+05
# min                               1.801800e+02  -13294.000000  4.500000e+04
# 25%                               6.756730e+04   -2922.500000  2.962800e+05
# ...

# %%
pd.DataFrame(explicative_data.dtypes).to_json(default_handler=str)
# Out:
# '{"0":{"EXT_SOURCE_1":"float64","EXT_SOURCE_2":"float64","EXT_SOURCE_3":"float64","client_installments_AMT_PAYMENT_min_sum":"float64","DAYS_EMPLOYED":"float64","AMT_CREDIT":"float64","DAYS_BIRTH":"int64","previous_CNT_PAYMENT_mean":"float64","bureau_DAYS_CREDIT_max":"float64","client_cash_CNT_INSTALMENT_FUTURE_min_mean":"float64"}}'

# %%
SCHEMA_PATH = os.path.join("../..","data","schema","typeAdapters.json")

# %%
d = pd.read_json(SCHEMA_PATH, typ='series')

# %%
d.iloc[0]
# Out:
# 'float'

# %%
for feature, value in explicative_data.mean().items():
    print(feature, value)
# Out:
# EXT_SOURCE_1 0.5504429448275862
# EXT_SOURCE_2 0.5480328559183674
# EXT_SOURCE_3 0.4673594288888889
# client_installments_AMT_PAYMENT_min_sum 441949.3614255319
# DAYS_EMPLOYED -2643.7906976744184
# AMT_CREDIT 512994.0306122449
# DAYS_BIRTH -15895.959183673469
# previous_CNT_PAYMENT_mean 15.968672234042554
# bureau_DAYS_CREDIT_max -420.04347826086956
# client_cash_CNT_INSTALMENT_FUTURE_min_mean 1.2466779614583332

# %%
from pydantic import TypeAdapter, ValidationError

a = TypeAdapter(eval("int"))

# %%
pd.DataFrame(explicative_data.mean()).reset_index()
# Out:
#                                         index              0
# 0                                EXT_SOURCE_1       0.550443
# 1                                EXT_SOURCE_2       0.548033
# 2                                EXT_SOURCE_3       0.467359
# 3     client_installments_AMT_PAYMENT_min_sum  441949.361426
# 4                               DAYS_EMPLOYED   -2643.790698
# 5                                  AMT_CREDIT  512994.030612
# 6                                  DAYS_BIRTH  -15895.959184
# 7                   previous_CNT_PAYMENT_mean      15.968672
# 8                      bureau_DAYS_CREDIT_max    -420.043478
# 9  client_cash_CNT_INSTALMENT_FUTURE_min_mean       1.246678

# %%
for a, b in pd.DataFrame(explicative_data.mean()).reset_index().to_dict().items():
    print(a,b)
# Out:
# index {0: 'EXT_SOURCE_1', 1: 'EXT_SOURCE_2', 2: 'EXT_SOURCE_3', 3: 'client_installments_AMT_PAYMENT_min_sum', 4: 'DAYS_EMPLOYED', 5: 'AMT_CREDIT', 6: 'DAYS_BIRTH', 7: 'previous_CNT_PAYMENT_mean', 8: 'bureau_DAYS_CREDIT_max', 9: 'client_cash_CNT_INSTALMENT_FUTURE_min_mean'}
# 0 {0: 0.5504429448275862, 1: 0.5480328559183674, 2: 0.4673594288888889, 3: 441949.3614255319, 4: -2643.7906976744184, 5: 512994.0306122449, 6: -15895.959183673469, 7: 15.968672234042554, 8: -420.04347826086956, 9: 1.2466779614583332}

# %%
for a, b in pd.DataFrame(explicative_data.mean()).T.iloc[0,:].items():
    print(a, b)
# Out:
# EXT_SOURCE_1 0.5504429448275862
# EXT_SOURCE_2 0.5480328559183674
# EXT_SOURCE_3 0.4673594288888889
# client_installments_AMT_PAYMENT_min_sum 441949.3614255319
# DAYS_EMPLOYED -2643.7906976744184
# AMT_CREDIT 512994.0306122449
# DAYS_BIRTH -15895.959183673469
# previous_CNT_PAYMENT_mean 15.968672234042554
# bureau_DAYS_CREDIT_max -420.04347826086956
# client_cash_CNT_INSTALMENT_FUTURE_min_mean 1.2466779614583332

# %%
list(explicative_data.mean().index)
# Out:
# ['EXT_SOURCE_1',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_3',
#  'client_installments_AMT_PAYMENT_min_sum',
#  'DAYS_EMPLOYED',
#  'AMT_CREDIT',
#  'DAYS_BIRTH',
#  'previous_CNT_PAYMENT_mean',
#  'bureau_DAYS_CREDIT_max',
#  'client_cash_CNT_INSTALMENT_FUTURE_min_mean']

# %%
[list(data.columns) for q in list(explicative_data.mean().index)]
# Out:
# [['SK_ID_CURR',
#   'CNT_CHILDREN',
#   'AMT_INCOME_TOTAL',
#   'AMT_CREDIT',
#   'REGION_POPULATION_RELATIVE',
#   'DAYS_BIRTH',
#   'DAYS_EMPLOYED',
#   'DAYS_REGISTRATION',
#   'DAYS_ID_PUBLISH',
#   'OWN_CAR_AGE',
#   'FLAG_WORK_PHONE',
#   'REGION_RATING_CLIENT',
#   'HOUR_APPR_PROCESS_START',
#   'REG_CITY_NOT_LIVE_CITY',
#   'EXT_SOURCE_1',
#   'EXT_SOURCE_2',
#   'EXT_SOURCE_3',
#   'APARTMENTS_AVG',
#   'BASEMENTAREA_AVG',
#   'YEARS_BEGINEXPLUATATION_AVG',
#   'YEARS_BUILD_AVG',
#   'COMMONAREA_AVG',
#   'ENTRANCES_AVG',
#   'FLOORSMAX_AVG',
#   'LANDAREA_AVG',
#   'NONLIVINGAPARTMENTS_AVG',
#   'NONLIVINGAREA_AVG',
#   'OBS_30_CNT_SOCIAL_CIRCLE',
#   'DEF_30_CNT_SOCIAL_CIRCLE',
#   'DAYS_LAST_PHONE_CHANGE',
#   'FLAG_DOCUMENT_3',
#   'FLAG_DOCUMENT_13',
#   'FLAG_DOCUMENT_16',
#   'FLAG_DOCUMENT_18',
#   'AMT_REQ_CREDIT_BUREAU_DAY',
#   'AMT_REQ_CREDIT_BUREAU_MON',
#   'AMT_REQ_CREDIT_BUREAU_QRT',
#   'AMT_REQ_CREDIT_BUREAU_YEAR',
#   'bureau_CREDIT_ACTIVE_Sold_mean',
# ...

# %%
pd.DataFrame(columns = [1,2]).empty
# Out:
# True
